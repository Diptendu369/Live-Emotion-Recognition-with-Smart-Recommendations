# %%
import cv2
import time
from deepface import DeepFace
# optional: from fer import FER  # if you want to try FER-based emotion detector
# Out:
# WARNING:tensorflow:From C:\Users\Diptendu Kumar Jashu\AppData\Roaming\Python\Python313\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def draw_label(img, text, x, y, bg_color=(0, 0, 0), text_color=(255,255,255), font_scale=0.6, thickness=1):
    font = cv2.FONT_HERSHEY_SIMPLEX
    (w, h), _ = cv2.getTextSize(text, font, font_scale, thickness)
    cv2.rectangle(img, (x, y - h - 10), (x + w + 6, y + 4), bg_color, -1)
    cv2.putText(img, text, (x + 2, y - 4), font, font_scale, text_color, thickness, cv2.LINE_AA)

# %%
# Try to use OpenCV's default face cascade. This file ships with opencv-python.
# If this fails, you can use DeepFace's detector_backend='opencv' and it'll use DNN or MTCNN.
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

def detect_faces_opencv(gray_frame):
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5, minSize=(60,60))
    return faces

# %%
# This function uses DeepFace.analyze for a face ROI.
# Note: we purposely DO NOT request 'race' from DeepFace.
def analyze_face_with_deepface(face_img):
    # DeepFace expects BGR images (as OpenCV), but will handle conversions internally.
    # actions can include 'age', 'gender', 'emotion' (we exclude 'race').
    try:
        result = DeepFace.analyze(face_img, actions=['age','gender','emotion'], enforce_detection=False, detector_backend='opencv')
        # result is a dict; on single face DeepFace returns dict with keys 'age','gender','dominant_emotion', 'emotion' etc.
        return result
    except Exception as e:
        # In case DeepFace fails (e.g., model loads), return None
        print("DeepFace analyze error:", e)
        return None

# %%
# %pip uninstall deepface -y
# %pip install deepface==0.0.79
# Out:
# Found existing installation: deepface 0.0.92
# Uninstalling deepface-0.0.92:
#   Successfully uninstalled deepface-0.0.92
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting deepface==0.0.79
#   Downloading deepface-0.0.79-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (2.2.6)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (2.3.2)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (4.67.1)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (5.2.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (11.3.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (4.12.0.88)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (2.20.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (3.11.3)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (3.1.2)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (1.0.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (0.7.1)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from deepface==0.0.79) (23.0.0)
# Requirement already satisfied: termcolor in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from fire>=0.4.0->deepface==0.0.79) (3.1.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from Flask>=1.1.2->deepface==0.0.79) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from Flask>=1.1.2->deepface==0.0.79) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from Flask>=1.1.2->deepface==0.0.79) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from Flask>=1.1.2->deepface==0.0.79) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from Flask>=1.1.2->deepface==0.0.79) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from Flask>=1.1.2->deepface==0.0.79) (3.1.3)
# Requirement already satisfied: colorama in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from click>=8.1.3->Flask>=1.1.2->deepface==0.0.79) (0.4.6)
# Requirement already satisfied: beautifulsoup4 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from gdown>=3.10.1->deepface==0.0.79) (4.13.5)
# Requirement already satisfied: filelock in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from gdown>=3.10.1->deepface==0.0.79) (3.18.0)
# Requirement already satisfied: requests[socks] in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from gdown>=3.10.1->deepface==0.0.79) (2.32.4)
# Requirement already satisfied: packaging in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from gunicorn>=20.1.0->deepface==0.0.79) (25.0)
# Requirement already satisfied: absl-py in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from keras>=2.2.0->deepface==0.0.79) (2.3.1)
# Requirement already satisfied: rich in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from keras>=2.2.0->deepface==0.0.79) (14.1.0)
# Requirement already satisfied: namex in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from keras>=2.2.0->deepface==0.0.79) (0.1.0)
# Requirement already satisfied: h5py in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from keras>=2.2.0->deepface==0.0.79) (3.14.0)
# Requirement already satisfied: optree in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from keras>=2.2.0->deepface==0.0.79) (0.17.0)
# Requirement already satisfied: ml-dtypes in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from keras>=2.2.0->deepface==0.0.79) (0.5.3)
# Requirement already satisfied: joblib>=1.4.2 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from mtcnn>=0.1.0->deepface==0.0.79) (1.5.1)
# Requirement already satisfied: lz4>=4.3.3 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from mtcnn>=0.1.0->deepface==0.0.79) (4.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from pandas>=0.23.4->deepface==0.0.79) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from pandas>=0.23.4->deepface==0.0.79) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from pandas>=0.23.4->deepface==0.0.79) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=0.23.4->deepface==0.0.79) (1.17.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (6.32.0)
# Requirement already satisfied: setuptools in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (80.9.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorflow>=1.9.0->deepface==0.0.79) (2.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from requests[socks]->gdown>=3.10.1->deepface==0.0.79) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from requests[socks]->gdown>=3.10.1->deepface==0.0.79) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from requests[socks]->gdown>=3.10.1->deepface==0.0.79) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from requests[socks]->gdown>=3.10.1->deepface==0.0.79) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow>=1.9.0->deepface==0.0.79) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow>=1.9.0->deepface==0.0.79) (0.7.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface==0.0.79) (0.45.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface==0.0.79) (2.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from requests[socks]->gdown>=3.10.1->deepface==0.0.79) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from rich->keras>=2.2.0->deepface==0.0.79) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from rich->keras>=2.2.0->deepface==0.0.79) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\diptendu kumar jashu\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface==0.0.79) (0.1.2)
# Downloading deepface-0.0.79-py3-none-any.whl (49 kB)
# Installing collected packages: deepface
# Successfully installed deepface-0.0.79
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import time
from deepface import DeepFace

# ------------------------------
# Helper: draw text with background
# ------------------------------
def draw_label(frame, text, x, y, bg_color=(0, 0, 0), text_color=(255, 255, 255)):
    font = cv2.FONT_HERSHEY_SIMPLEX
    scale = 0.6
    thickness = 2
    (tw, th), baseline = cv2.getTextSize(text, font, scale, thickness)
    cv2.rectangle(frame, (x, y - th - baseline), (x + tw, y + baseline), bg_color, -1)
    cv2.putText(frame, text, (x, y), font, scale, text_color, thickness, cv2.LINE_AA)

# ------------------------------
# Face detector (OpenCV Haar)
# ------------------------------
def detect_faces_opencv(gray_frame):
    face_cascade = cv2.CascadeClassifier(
        cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
    )
    faces = face_cascade.detectMultiScale(gray_frame, 1.3, 5)
    return faces

# ------------------------------
# Real-time webcam loop
# ------------------------------
USE_DEEPFACE = True   # Toggle DeepFace analysis
SHOW_GENDER = True    # Toggle gender display

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise RuntimeError("❌ Could not open webcam. Check device index or permissions.")

fps_time = time.time()
frame_count = 0

try:
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = detect_faces_opencv(gray)

        for (x, y, w, h) in faces:
            pad = int(0.05 * w)
            x1, y1 = max(x - pad, 0), max(y - pad, 0)
            x2, y2 = min(x + w + pad, frame.shape[1]), min(y + h + pad, frame.shape[0])
            face_img = frame[y1:y2, x1:x2].copy()

            label_parts = []

            if USE_DEEPFACE:
                try:
                    res = DeepFace.analyze(
                        face_img,
                        actions=['age', 'gender', 'emotion'],  # add 'race' if needed
                        detector_backend='opencv',
                        enforce_detection=False
                    )
                    if isinstance(res, list):
                        res = res[0]  # take first face dict

                    # Age
                    age = res.get("age", None)
                    if age is not None:
                        label_parts.append(f"Age:{int(age)}")

                    # Gender
                    if SHOW_GENDER:
                        gender = res.get("dominant_gender", "")
                        if gender:
                            label_parts.append(gender.capitalize())

                    # Emotion
                    emotion = res.get("dominant_emotion", "")
                    if emotion:
                        label_parts.append(emotion.capitalize())

                except Exception as e:
                    print("DeepFace error:", e)

            # Draw bounding box + label
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label_text = " | ".join(label_parts) if label_parts else "Face"
            draw_label(frame, label_text, x1, y1)

        # FPS counter
        frame_count += 1
        if frame_count % 10 == 0:
            now = time.time()
            fps = 10.0 / (now - fps_time)
            fps_time = now
            draw_label(frame, f"FPS: {fps:.1f}", 10, 30, bg_color=(50, 50, 50))

        cv2.imshow("Real-time Age/Gender/Emotion Demo", frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

finally:
    cap.release()
    cv2.destroyAllWindows()
# Out:
# Action: emotion: 100%|██████████| 3/3 [00:02<00:00,  1.18it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 10.11it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 10.55it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 10.85it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.29it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.01it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.33it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 10.90it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 10.97it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 10.98it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 10.98it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.11it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.64it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.74it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.38it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.90it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.98it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.90it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.82it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.64it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.03it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.10it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.78it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.71it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.99it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.02it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.78it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.69it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.85it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.61it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.16it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.72it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.90it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.55it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.02it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.84it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.92it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.23it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.92it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.24it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.77it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.99it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.10it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.62it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.15it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.83it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.93it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.93it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.78it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.11it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.40it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.05it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.89it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.80it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.20it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.91it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.03it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.10it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.13it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 10.63it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.85it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.95it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.86it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.18it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.73it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.84it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.83it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.89it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.92it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.09it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.88it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.15it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.03it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.07it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.14it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.66it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.34it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.93it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.83it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.60it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.96it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.67it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.01it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.99it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.87it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.76it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.21it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.95it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.83it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.80it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.16it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.06it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.66it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.16it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.24it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.78it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.55it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.14it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.91it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.74it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.95it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.48it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.09it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.52it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.12it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.03it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.07it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.91it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.91it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.28it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.82it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.74it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.06it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.96it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.82it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.74it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.11it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.07it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.03it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.10it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.74it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.79it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.05it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.67it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.09it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.72it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.06it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.98it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.08it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.84it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.71it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.65it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.87it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.04it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.93it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.63it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.52it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.07it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.08it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.93it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.18it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.10it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.00it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.87it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.64it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.19it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.92it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.67it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.73it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.02it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.86it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.03it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.03it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.22it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.96it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 11.98it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 12.21it/s]
